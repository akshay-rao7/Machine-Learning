# %% [markdown]
# ### Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Reading the data

# %%
# Reading the data
df = pd.read_csv("insurance.csv")

# %% [markdown]
# ### Number of rows and columns in the data

# %%
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# ### Analysing the data

# %%
#display the first 5 rows - 5 is default
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#display the last 5 rows - 5 is default
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
#type of data in each columns
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
for col in list(df):
    print(col)
    print(df[col].unique())
    print("----------------------------------------------------------------------")
# Out:
# age
# [19 18 28 33 32 31 46 37 60 25 62 23 56 27 52 30 34 59 63 55 22 26 35 24
#  41 38 36 21 48 40 58 53 43 64 20 61 44 57 29 45 54 49 47 51 42 50 39]
# ----------------------------------------------------------------------
# sex
# ['female' 'male']
# ----------------------------------------------------------------------
# bmi
# [27.9   33.77  33.    22.705 28.88  25.74  33.44  27.74  29.83  25.84
#  26.22  26.29  34.4   39.82  42.13  24.6   30.78  23.845 40.3   35.3
#  36.005 32.4   34.1   31.92  28.025 27.72  23.085 32.775 17.385 36.3
#  35.6   26.315 28.6   28.31  36.4   20.425 32.965 20.8   36.67  39.9
#  26.6   36.63  21.78  30.8   37.05  37.3   38.665 34.77  24.53  35.2
#  35.625 33.63  28.    34.43  28.69  36.955 31.825 31.68  22.88  37.335
#  27.36  33.66  24.7   25.935 22.42  28.9   39.1   36.19  23.98  24.75
#  28.5   28.1   32.01  27.4   34.01  29.59  35.53  39.805 26.885 38.285
#  37.62  41.23  34.8   22.895 31.16  27.2   26.98  39.49  24.795 31.3
# ...

# %% [markdown]
# #### Convert object to int

# %%
df['smoker'].replace({'yes':1, 'no':0}, inplace=True)

# %%
df['sex'].replace({'male':1, 'female':0}, inplace=True)

# %%
df['region'].replace({'southwest':1, 'southeast':2,'northwest':3, 'northeast':4}, inplace=True)

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# bmi         float64
# children      int64
# smoker        int64
# region        int64
# charges     float64
# dtype: object

# %% [markdown]
# ### Checking for null values

# %%
#checking for null values 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   int64
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   int64
#  5   region    1338 non-null   int64
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(5)
# memory usage: 73.3 KB

# %%
#checking for any null/missing values in the dataset 
df.isnull().any().sum()
# Out:
# 0

# %% [markdown]
# ### 5 point summary

# %%
df.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges
# count  1338.000000   1338.000000
# mean      2.484305  13270.422265
# std       1.104885  12110.011237
# min       1.000000   1121.873900
# 25%       2.000000   4740.287150
# 50%       2.000000   9382.033000
# 75%       3.000000  16639.912515
# max       4.000000  63770.428010

# %% [markdown]
# ### Distribution and skewness of ‘bmi’, ‘age’ and ‘charges’ columns. Also finding the outliers.

# %% [markdown]
# #### Age

# %%
sns.distplot(df['age'])
print(df['age'].skew())
# Out:
# 0.05567251565299186

# %%
sns.boxplot(df['age'])

# %% [markdown]
# #### BMI

# %%
sns.distplot(df['bmi'])
print(df['bmi'].skew())
# Out:
# 0.2840471105987448

# %%
sns.boxplot(df['bmi'])

# %%
#outliers are present in bmi

# %% [markdown]
# #### Charges

# %%
sns.distplot(df['charges'])
print(df['charges'].skew())
# Out:
# 1.5158796580240388

# %%
sns.boxplot(df['charges'])

# %%
#outliers are present in charges

# %% [markdown]
# ### Distribution of categorical columns (include children)

# %%
sns.distplot(df['smoker'])

# %%
sns.distplot(df['sex'])

# %%
sns.distplot(df['children'])

# %% [markdown]
# ### Pair plot that includes all the columns of the data frame

# %%
sns.pairplot(df)

# %% [markdown]
# ### Do charges of people who smoke differ significantly from the people who don't?

# %%
sns.barplot(x='smoker', y='charges',data=df)

# %%
#people who smoke pay higher charges compared to people who dont

# %% [markdown]
# ### Does bmi of males differ significantly from that of females?

# %%
sns.barplot(x='sex', y='bmi',data=df)

# %%
sns.scatterplot(x='bmi', y='sex', data=df, hue='sex')

# %%
# bmi of males and females do not differ significantly since the data points are overlapping

# %% [markdown]
# ### Is the proportion of smokers significantly different in different genders?

# %%
sns.barplot(x=df['smoker'], y= df['sex'],data=df)

# %%
# from the above figure we can interpret that males smoke more than females.

# %% [markdown]
# ### Is the distribution of bmi across women with no children, one child and two children, the same ?

# %%
sns.barplot(x=df['children'], y= df['bmi'],data=df)

# %%
# from the above figure we can interpret that bmi is not affected by the number of children a woman has.
